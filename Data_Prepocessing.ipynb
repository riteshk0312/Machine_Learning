# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Housing.csv

# %% [markdown]
# ### Import the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Data Loading

# %%
# Read the data

# %%
data=pd.read_csv(r"C:\Users\rites\Downloads\housing_dataset (1).csv")

# %%
data.head()
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East

# %%
data.tail()
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Home          128 non-null    int64
#  1   Price         128 non-null    int64
#  2   SqFt          128 non-null    int64
#  3   Bedrooms      128 non-null    int64
#  4   Bathrooms     128 non-null    int64
#  5   Offers        128 non-null    int64
#  6   Brick         128 non-null    object
#  7   Neighborhood  128 non-null    object
# dtypes: int64(6), object(2)
# memory usage: 8.1+ KB

# %%
data.describe()
# Out:
#              Home          Price         SqFt    Bedrooms   Bathrooms  \
# count  128.000000     128.000000   128.000000  128.000000  128.000000
# mean    64.500000  130427.343750  2000.937500    3.023438    2.445312
# std     37.094474   26868.770371   211.572431    0.725951    0.514492
# min      1.000000   69100.000000  1450.000000    2.000000    2.000000
# 25%     32.750000  111325.000000  1880.000000    3.000000    2.000000
# 50%     64.500000  125950.000000  2000.000000    3.000000    2.000000
# 75%     96.250000  148250.000000  2140.000000    3.000000    3.000000
# max    128.000000  211200.000000  2590.000000    5.000000    4.000000
#
#            Offers
# count  128.000000
# mean     2.578125
# std      1.069324
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      3.000000
# max      6.000000

# %% [markdown]
# ## Data cleaning

# %%
# missing values

# %%
data.isnull().sum()
# Out:
# Home            0
# Price           0
# SqFt            0
# Bedrooms        0
# Bathrooms       0
# Offers          0
# Brick           0
# Neighborhood    0
# dtype: int64

# %%
# Duplicate rows

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# in our data if we have duplicate

# %%
# remove duplicate
data=data.drop_duplicates()

# %%
data.shape
# no. of rows, no. of columns
# Out:
# (128, 8)

# %% [markdown]
# # EDA- Exploratory Data Analysis

# %%
# Univariate Analysis

# %%
import seaborn as sns

# %%
sns.histplot(data['Price'])

plt.title("Hist-Plot of Price")

plt.show()

# %%
sns.histplot(data['SqFt'])

plt.title("Hist-Plot of Sq-Ft")

plt.show()

# %%
sns.countplot(data=data, x=data['Bedrooms'])

plt.title("CountPlot of Bedrooms")

plt.show()

# %%
sns.boxplot(data['Offers'])

plt.title("Bo-Plot of Offers")

plt.show()

# %%
sns.violinplot(data['Price'])

plt.title("Violin-Plot of Price")

plt.show()

# %% [markdown]
# ### Bivariate analysis- Two columns

# %%
plt.scatter(x=data['SqFt'],y=data['Price'])
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Scatter plot between SqFt and Price')
plt.show()

# %%
plt.scatter(x=data['SqFt'],y=data['Bedrooms'])
plt.xlabel('Area')
plt.ylabel('Bedrooms')
plt.title('Scatter plot between Area and Bedrooms')
plt.show()

# %%
plt.scatter(x=data['SqFt'],y=data['Bathrooms'])
plt.xlabel('Area')
plt.ylabel('Bathrooms')
plt.title('Scatter plot between Area and Bathrooms')
plt.show()

# %%
plt.scatter(x=data['SqFt'],y=data['Offers'])
plt.xlabel('Area')
plt.ylabel('Offers')
plt.title('Scatter plot between Area and Offers')
plt.show()

# %%
sns.countplot(data = data, x=data['Brick'])

plt.title("Count-Plot of Price")

plt.show()

# %%
sns.countplot(data = data, x=data['Neighborhood'])

plt.title("Count-Plot of Price")

plt.show()

# %% [markdown]
# # Multivariate Analysis-two or more column

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
data['room_sqft']=data['SqFt']/data['Bedrooms']

# %%
data.head()
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood  \
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East
#
#    room_sqft
# 0      895.0
# 1      507.5
# 2      580.0
# 3      660.0
# 4      710.0

# %% [markdown]
# # Data Encoding

# %%
data.Neighborhood.value_counts()
# Out:
# Neighborhood
# East     45
# North    44
# West     39
# Name: count, dtype: int64

# %% [markdown]
# ### Dummy variable

# %%
data=pd.get_dummies(data)
data.head()
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers  room_sqft  Brick_No  \
# 0     1  114300  1790         2          2       2      895.0      True
# 1     2  114200  2030         4          2       3      507.5      True
# 2     3  114800  1740         3          2       1      580.0      True
# 3     4   94700  1980         3          2       3      660.0      True
# 4     5  119800  2130         3          3       3      710.0      True
#
#    Brick_Yes  Neighborhood_East  Neighborhood_North  Neighborhood_West
# 0      False               True               False              False
# 1      False               True               False              False
# 2      False               True               False              False
# 3      False               True               False              False
# 4      False               True               False              False

# %% [markdown]
# # Scaling

# %% [markdown]
# ## 1.Standard Scaling
# ## 2.Min Max Scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(data)
# Out:
# StandardScaler()

# %%
data_scaled=scaler.transform(data)

# %%
pd.DataFrame(data_scaled,columns=data.columns).head()
# Out:
#        Home     Price      SqFt  Bedrooms  Bathrooms    Offers  room_sqft  \
# 0 -1.718572 -0.602585 -1.000916 -1.415327  -0.868939 -0.542769   1.282356
# 1 -1.691507 -0.606321  0.137904  1.350503  -0.868939  0.396075  -1.195417
# 2 -1.664443 -0.583903 -1.238171 -0.032412  -0.868939 -1.481614  -0.731834
# 3 -1.637379 -1.334923 -0.099350 -0.032412  -0.868939  0.396075  -0.220294
# 4 -1.610315 -0.397082  0.612413 -0.032412   1.082362  0.396075   0.099419
#
#    Brick_No  Brick_Yes  Neighborhood_East  Neighborhood_North  \
# 0  0.698836  -0.698836           1.358103           -0.723747
# 1  0.698836  -0.698836           1.358103           -0.723747
# 2  0.698836  -0.698836           1.358103           -0.723747
# 3  0.698836  -0.698836           1.358103           -0.723747
# 4  0.698836  -0.698836           1.358103           -0.723747
#
#    Neighborhood_West
# 0          -0.661968
# 1          -0.661968
# 2          -0.661968
# 3          -0.661968
# 4          -0.661968
